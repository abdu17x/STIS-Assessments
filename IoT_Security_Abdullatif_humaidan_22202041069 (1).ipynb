# %%
import uuid
import datetime

def log(stage, msg):
    print(f"[{datetime.datetime.utcnow():%H:%M:%S}] {stage}: {msg}")

def lifecycle():
    log("Stage-1", "Threat model created – STRIDE applied")
    log("Stage-2", "Secure boot verified – firmware signature OK")
    log("Stage-3", f"Key injection complete – devID={uuid.uuid4().hex[:8]}")
    log("Stage-4", "OTA update verified – hash signature matches")
    log("Stage-5", "Device decommissioned – secrets wiped")

lifecycle()
# Out:
# [07:21:16] Stage-1: Threat model created – STRIDE applied
# [07:21:16] Stage-2: Secure boot verified – firmware signature OK
# [07:21:16] Stage-3: Key injection complete – devID=0814dae9
# [07:21:16] Stage-4: OTA update verified – hash signature matches
# [07:21:16] Stage-5: Device decommissioned – secrets wiped
# /tmp/ipython-input-3984015183.py:5: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   print(f"[{datetime.datetime.utcnow():%H:%M:%S}] {stage}: {msg}")
